# %%
from phidl import Device
from phidl import quickplot as qp # Rename "quickplot()" to the easier "qp()"
import phidl.geometry as pg
import layout

# %%
ls = layout.setup_layers()
P = pg.preview_layerset(ls)
qp(P)

# %%
T = layout.chip()

# %%
qp(T)

# %%
T.write_gds('test.gds')
# Out:
# 'test.gds'

# %%
# D = Device('Test')
# WG1 = layout.waveguide(width = 1.5, length=20)
# WG2 = layout.waveguide(width = 1.5, length=10)
# wg1 = D << WG1
# wg2 = D << WG2

# %%
# qp(WG1)

# %%
# D.add_label('This is a label x', position = wg1.center)

# %%
# D.write_gds('test.gds')
