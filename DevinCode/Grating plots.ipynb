# %%
import numpy as np
import matplotlib.pyplot as plt

import gratings

# %%
# k0, kbw, chirp, length, dutycycle
# Defaults: k0=1e6; kbw = 1e5; chirp = -2.5e6; length = 1e-2; dutycycle = 0.5
g = gratings.grating(dutycycle = 0.3)

# %%
gratings.plotgratingvector(g)

# %%
gratings.plotgratingperiod(g)

# %%
gratings.plotgrating(g)

# %%
gratings.plotRLV(g)

# %%
gratings.plotRLV(g,(40000, 120000))
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-7-475f794c1e8e> in <module>
# ----> 1 gratings.plotRLV(g,(40000, 120000))
#
# ~\OneDrive\Documents\GitHub\Photonics_python_Luis\DevinCode\gratings.py in plotRLV(g, kbounds)
#     101     fig = plt.figure()
#     102     ax1 = fig.add_subplot(111)
# --> 103     ax1.set_xlim(kstart, kend)
#     104
#     105     ax1.ticklabel_format(style='sci', useOffset = False)
#
# UnboundLocalError: local variable 'kstart' referenced before assignment

# %%
gratings.plotRLV(g, (0, 10*g.k0))
