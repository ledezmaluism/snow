# %%
import numpy as np
import matplotlib.pyplot as plt

import customwaveguides as cwgs

# %%
um = 1e-6; nm = 1e-9; cm = 1e-2

startwidth = 1.85*um #top width - really should be fct of z

# %%
slope = 100*nm / cm # for every cm in z, width changes by 100 nm
slope = 500*nm / cm # for every cm in z, width changes by 100 nm

linwidthfct = cwgs.linearwidthfct(startwidth, slope)

# %%
cwg = cwgs.customwaveguide(linwidthfct, length = 2*cm)
wl = 1*um
wlbounds = (0.5*um, 3*um)

# %%
cwgs.plotnvswl(cwg, 0, wlbounds, 50)

# %%
cwgs.plotnarray(cwg,wl)
print("Wavelength plotted = " + str(wl/um) + "um")
# Out:
# Wavelength plotted = 1.0um

# %%
cwgs.heatmapnaa(cwg, wlbounds, 50)
