# %% [markdown]
# Get modes for different frequencies and geometries.
# Just get the scalar figures of merit and save to files.

# %%
import lumerical as lum
import numpy as  np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import imp
import time
import matplotlib.patches as patches

from scipy.constants import pi, c

lumapi = imp.load_source("lumapi", "C:/Program Files/Lumerical/2020a/api/python/lumapi.py")
MODE = lumapi.MODE("Template_Luis.lms")

# %% [markdown]
# Units

# %%
um = 1e-6
nm = 1e-9
THz = 1e12

# %% [markdown]
# Materials

# %%
material_substrate = "SiO2_analytic"
material_thinfilm = "LN_analytic_MgO_doped_xne"

# %% [markdown]
# Main waveguide parameters

# %%
h_LN = 700*nm
h_etch = 500*nm
h_slab = h_LN - h_etch

width_top = 1*um

w_slab = 20*um
h_margin = 5*um
h_substrate = 5*um


theta = 60
wg_length = 10*um #Useless in MODE
width_top_base = width_top + 2*h_etch/np.tan(theta*pi/180)
w_sidewall = h_etch/np.tan(theta*pi/180)

print('slab = %.3f um' %(h_slab/um))
print('width at the base = %.3f um' %(width_top_base/um))

#Draw it
fig,ax = plt.subplots()
substrate = patches.Rectangle((-w_slab/2/um,-h_substrate/um), w_slab/um, h_substrate/um,
                             linewidth=1, edgecolor='r', facecolor='r', alpha=0.5)
v_ridge = np.array([[-width_top/2-w_sidewall,h_slab], [-width_top/2,h_LN],
                   [width_top/2,h_LN], [width_top/2+w_sidewall,h_slab],
                   [w_slab/2,h_slab], [w_slab/2,0], 
                   [-w_slab/2,0], [-w_slab/2, h_slab] ] )/um
ridge = patches.Polygon(v_ridge, linewidth=1, 
                       edgecolor='k', facecolor='blue', alpha=0.7)

ax.add_patch(substrate)
ax.add_patch(ridge)

plt.axis('equal')
plt.tight_layout()
plt.show()
# Out:
# slab = 0.200 um
# width at the base = 1.577 um

# %% [markdown]
# ## Parametric sweep

# %%
h_LN = 700*nm
# freq = np.arange(100, 751, 20)*THz
wavelengths = np.arange(900, 2300, 50)*nm
freq = c/wavelengths
width = np.arange(700, 3000, 100)*nm
etch = np.arange(250, 251, 100)*nm

Nsims = freq.size * width.size * etch.size
print('Number of sims needed = %i' %(Nsims))
print(Nsims*2/60)
# Out:
# Number of sims needed = 644
# 21.466666666666665

# %%
pad = lambda a, i: a[0: i] if a.shape[0] > i else np.hstack((a, np.zeros(i - a.shape[0])))

# %%
nmodes = 4 #will save first 4 modes only but will use symmetry to weed out symmetric TM modes

neff = np.zeros((freq.size, width.size, etch.size, nmodes))
ng = np.zeros((freq.size, width.size, etch.size, nmodes))
loss = np.zeros((freq.size, width.size, etch.size, nmodes))
te = np.zeros((freq.size, width.size, etch.size, nmodes))

tic_total = time.time()
Ndone = 0
for ke in range(etch.size):
    for kw in range(width.size):
        for kf in range(freq.size):
            tic = time.time()
            MODE.switchtolayout()

            h_etch = etch[ke]
            width_top = width[kw]
            f = freq[kf]
            wavelength = c/f
             
            meshsize = wavelength/10
            finemesh = wavelength/50
                
            #Draw waveguide and solver
            lum.draw_wg(MODE, material_thinfilm, material_substrate,
                          h_LN, h_substrate, h_etch, width_top, w_slab, theta, wg_length)
            lum.add_fine_mesh(MODE, finemesh, h_LN, width_top_base, x_factor=1.2, y_factor=1.5)
            lum.add_2D_mode_solver(MODE, meshsize, h_LN, h_substrate, 
                                     w_slab, wg_length, h_margin, symmetry='TE')

            _neff, _ng, _loss, _te = lum.solve_mode(MODE, wavelength, nmodes=20)

            neff[kf, kw, ke, :] = pad(_neff, nmodes)
            ng[kf, kw, ke, :] = pad(_ng, nmodes)
            loss[kf, kw, ke, :]  = pad(_loss, nmodes)
            te[kf, kw, ke, :]  = pad(_te, nmodes)
            
            Ndone += 1
            t_sim = time.time() - tic
            print('Completed %0.1f %% (time last sim = %0.1f m)' %(Ndone/Nsims*100, t_sim/60))

timestamp = str(round(time.time()))
data_filename = 'Data\LNOI_%inm_geom_sweep_' %(int(h_LN/nm))
data_filename = data_filename.replace('.','p')
data_filename += timestamp
np.savez(data_filename, freq=freq, width=width, etch=etch,
         neff=neff, tepf=te, loss=loss, ng=ng, #Main results
         h_LN=h_LN, theta=theta, h_substrate=h_substrate, w_slab=w_slab, h_margin=h_margin, 
         meshsize=meshsize, finemesh=finemesh, 
         material_substrate=material_substrate, material_thinfilm=material_thinfilm) 
            
    
MODE.close()
t_elapsed = time.time() - tic_total
print('Total time = %.1f  hr' %(t_elapsed/3600) )
# Out:
# Completed 0.2 % (time last sim = 0.3 m)
# Completed 0.3 % (time last sim = 0.2 m)
# Completed 0.5 % (time last sim = 0.2 m)
# Completed 0.6 % (time last sim = 0.2 m)
# Completed 0.8 % (time last sim = 0.2 m)
# Completed 0.9 % (time last sim = 0.1 m)
# Completed 1.1 % (time last sim = 0.2 m)
# Completed 1.2 % (time last sim = 0.1 m)
# Completed 1.4 % (time last sim = 0.1 m)
# Completed 1.6 % (time last sim = 0.1 m)
# Completed 1.7 % (time last sim = 0.1 m)
# Completed 1.9 % (time last sim = 0.2 m)
# Completed 2.0 % (time last sim = 0.1 m)
# Completed 2.2 % (time last sim = 0.1 m)
# Completed 2.3 % (time last sim = 0.1 m)
# Completed 2.5 % (time last sim = 0.1 m)
# Completed 2.6 % (time last sim = 0.1 m)
# Completed 2.8 % (time last sim = 0.1 m)
# Completed 3.0 % (time last sim = 0.1 m)
# Completed 3.1 % (time last sim = 0.1 m)
# Completed 3.3 % (time last sim = 0.1 m)
# Completed 3.4 % (time last sim = 0.1 m)
# Completed 3.6 % (time last sim = 0.1 m)
# Completed 3.7 % (time last sim = 0.1 m)
# Completed 3.9 % (time last sim = 0.1 m)
# Completed 4.0 % (time last sim = 0.1 m)
# Completed 4.2 % (time last sim = 0.1 m)
# Completed 4.3 % (time last sim = 0.1 m)
# Completed 4.5 % (time last sim = 0.3 m)
# Completed 4.7 % (time last sim = 0.2 m)
# Completed 4.8 % (time last sim = 0.2 m)
# Completed 5.0 % (time last sim = 0.2 m)
# Completed 5.1 % (time last sim = 0.2 m)
# Completed 5.3 % (time last sim = 0.2 m)
# Completed 5.4 % (time last sim = 0.2 m)
# Completed 5.6 % (time last sim = 0.1 m)
# Completed 5.7 % (time last sim = 0.1 m)
# Completed 5.9 % (time last sim = 0.1 m)
# Completed 6.1 % (time last sim = 0.1 m)
# Completed 6.2 % (time last sim = 0.1 m)
# Completed 6.4 % (time last sim = 0.1 m)
# Completed 6.5 % (time last sim = 0.1 m)
# Completed 6.7 % (time last sim = 0.1 m)
# Completed 6.8 % (time last sim = 0.1 m)
# Completed 7.0 % (time last sim = 0.1 m)
# Completed 7.1 % (time last sim = 0.1 m)
# Completed 7.3 % (time last sim = 0.1 m)
# Completed 7.5 % (time last sim = 0.1 m)
# Completed 7.6 % (time last sim = 0.1 m)
# Completed 7.8 % (time last sim = 0.1 m)
# Completed 7.9 % (time last sim = 0.1 m)
# Completed 8.1 % (time last sim = 0.1 m)
# Completed 8.2 % (time last sim = 0.1 m)
# Completed 8.4 % (time last sim = 0.1 m)
# Completed 8.5 % (time last sim = 0.1 m)
# Completed 8.7 % (time last sim = 0.1 m)
# Completed 8.9 % (time last sim = 0.3 m)
# Completed 9.0 % (time last sim = 0.2 m)
# Completed 9.2 % (time last sim = 0.2 m)
# Completed 9.3 % (time last sim = 0.2 m)
# Completed 9.5 % (time last sim = 0.2 m)
# Completed 9.6 % (time last sim = 0.2 m)
# Completed 9.8 % (time last sim = 0.1 m)
# Completed 9.9 % (time last sim = 0.2 m)
# Completed 10.1 % (time last sim = 0.1 m)
# Completed 10.2 % (time last sim = 0.1 m)
# Completed 10.4 % (time last sim = 0.1 m)
# Completed 10.6 % (time last sim = 0.1 m)
# Completed 10.7 % (time last sim = 0.1 m)
# Completed 10.9 % (time last sim = 0.1 m)
# Completed 11.0 % (time last sim = 0.1 m)
# Completed 11.2 % (time last sim = 0.1 m)
# Completed 11.3 % (time last sim = 0.1 m)
# Completed 11.5 % (time last sim = 0.1 m)
# Completed 11.6 % (time last sim = 0.1 m)
# Completed 11.8 % (time last sim = 0.1 m)
# Completed 12.0 % (time last sim = 0.1 m)
# Completed 12.1 % (time last sim = 0.1 m)
# Completed 12.3 % (time last sim = 0.1 m)
# Completed 12.4 % (time last sim = 0.1 m)
# Completed 12.6 % (time last sim = 0.1 m)
# Completed 12.7 % (time last sim = 0.1 m)
# Completed 12.9 % (time last sim = 0.1 m)
# Completed 13.0 % (time last sim = 0.1 m)
# Completed 13.2 % (time last sim = 0.2 m)
# Completed 13.4 % (time last sim = 0.2 m)
# Completed 13.5 % (time last sim = 0.2 m)
# Completed 13.7 % (time last sim = 0.2 m)
# Completed 13.8 % (time last sim = 0.2 m)
# Completed 14.0 % (time last sim = 0.2 m)
# Completed 14.1 % (time last sim = 0.1 m)
# Completed 14.3 % (time last sim = 0.2 m)
# Completed 14.4 % (time last sim = 0.2 m)
# Completed 14.6 % (time last sim = 0.1 m)
# Completed 14.8 % (time last sim = 0.1 m)
# Completed 14.9 % (time last sim = 0.1 m)
# Completed 15.1 % (time last sim = 0.1 m)
# Completed 15.2 % (time last sim = 0.1 m)
# Completed 15.4 % (time last sim = 0.1 m)
# Completed 15.5 % (time last sim = 0.1 m)
# Completed 15.7 % (time last sim = 0.1 m)
# Completed 15.8 % (time last sim = 0.1 m)
# Completed 16.0 % (time last sim = 0.1 m)
# Completed 16.1 % (time last sim = 0.1 m)
# Completed 16.3 % (time last sim = 0.1 m)
# Completed 16.5 % (time last sim = 0.1 m)
# Completed 16.6 % (time last sim = 0.1 m)
# Completed 16.8 % (time last sim = 0.1 m)
# Completed 16.9 % (time last sim = 0.1 m)
# Completed 17.1 % (time last sim = 0.1 m)
# Completed 17.2 % (time last sim = 0.1 m)
# Completed 17.4 % (time last sim = 0.1 m)
# Completed 17.5 % (time last sim = 0.3 m)
# Completed 17.7 % (time last sim = 0.2 m)
# Completed 17.9 % (time last sim = 0.2 m)
# Completed 18.0 % (time last sim = 0.2 m)
# Completed 18.2 % (time last sim = 0.2 m)
# Completed 18.3 % (time last sim = 0.2 m)
# Completed 18.5 % (time last sim = 0.1 m)
# Completed 18.6 % (time last sim = 0.2 m)
# Completed 18.8 % (time last sim = 0.1 m)
# Completed 18.9 % (time last sim = 0.1 m)
# Completed 19.1 % (time last sim = 0.1 m)
# Completed 19.3 % (time last sim = 0.1 m)
# Completed 19.4 % (time last sim = 0.1 m)
# Completed 19.6 % (time last sim = 0.1 m)
# Completed 19.7 % (time last sim = 0.1 m)
# Completed 19.9 % (time last sim = 0.1 m)
# Completed 20.0 % (time last sim = 0.1 m)
# Completed 20.2 % (time last sim = 0.1 m)
# Completed 20.3 % (time last sim = 0.1 m)
# Completed 20.5 % (time last sim = 0.1 m)
# Completed 20.7 % (time last sim = 0.1 m)
# Completed 20.8 % (time last sim = 0.1 m)
# Completed 21.0 % (time last sim = 0.1 m)
# Completed 21.1 % (time last sim = 0.1 m)
# Completed 21.3 % (time last sim = 0.1 m)
# Completed 21.4 % (time last sim = 0.1 m)
# Completed 21.6 % (time last sim = 0.1 m)
# Completed 21.7 % (time last sim = 0.1 m)
# Completed 21.9 % (time last sim = 0.2 m)
# Completed 22.0 % (time last sim = 0.2 m)
# Completed 22.2 % (time last sim = 0.2 m)
# Completed 22.4 % (time last sim = 0.3 m)
# Completed 22.5 % (time last sim = 0.1 m)
# Completed 22.7 % (time last sim = 0.2 m)
# Completed 22.8 % (time last sim = 0.2 m)
# Completed 23.0 % (time last sim = 0.1 m)
# Completed 23.1 % (time last sim = 0.1 m)
# Completed 23.3 % (time last sim = 0.1 m)
# Completed 23.4 % (time last sim = 0.2 m)
# Completed 23.6 % (time last sim = 0.1 m)
# Completed 23.8 % (time last sim = 0.1 m)
# Completed 23.9 % (time last sim = 0.1 m)
# Completed 24.1 % (time last sim = 0.1 m)
# Completed 24.2 % (time last sim = 0.1 m)
# Completed 24.4 % (time last sim = 0.1 m)
# Completed 24.5 % (time last sim = 0.1 m)
# Completed 24.7 % (time last sim = 0.1 m)
# Completed 24.8 % (time last sim = 0.1 m)
# Completed 25.0 % (time last sim = 0.1 m)
# Completed 25.2 % (time last sim = 0.1 m)
# Completed 25.3 % (time last sim = 0.1 m)
# Completed 25.5 % (time last sim = 0.1 m)
# Completed 25.6 % (time last sim = 0.1 m)
# Completed 25.8 % (time last sim = 0.1 m)
# Completed 25.9 % (time last sim = 0.1 m)
# Completed 26.1 % (time last sim = 0.1 m)
# Completed 26.2 % (time last sim = 0.3 m)
# Completed 26.4 % (time last sim = 0.2 m)
# Completed 26.6 % (time last sim = 0.2 m)
# Completed 26.7 % (time last sim = 0.2 m)
# Completed 26.9 % (time last sim = 0.2 m)
# Completed 27.0 % (time last sim = 0.1 m)
# Completed 27.2 % (time last sim = 0.2 m)
# Completed 27.3 % (time last sim = 0.2 m)
# Completed 27.5 % (time last sim = 0.1 m)
# Completed 27.6 % (time last sim = 0.1 m)
# Completed 27.8 % (time last sim = 0.1 m)
# Completed 28.0 % (time last sim = 0.1 m)
# Completed 28.1 % (time last sim = 0.1 m)
# Completed 28.3 % (time last sim = 0.1 m)
# Completed 28.4 % (time last sim = 0.1 m)
# Completed 28.6 % (time last sim = 0.1 m)
# Completed 28.7 % (time last sim = 0.1 m)
# Completed 28.9 % (time last sim = 0.1 m)
# Completed 29.0 % (time last sim = 0.1 m)
# Completed 29.2 % (time last sim = 0.1 m)
# Completed 29.3 % (time last sim = 0.1 m)
# Completed 29.5 % (time last sim = 0.1 m)
# Completed 29.7 % (time last sim = 0.1 m)
# Completed 29.8 % (time last sim = 0.1 m)
# Completed 30.0 % (time last sim = 0.1 m)
# Completed 30.1 % (time last sim = 0.1 m)
# Completed 30.3 % (time last sim = 0.1 m)
# Completed 30.4 % (time last sim = 0.1 m)
# Completed 30.6 % (time last sim = 0.3 m)
# Completed 30.7 % (time last sim = 0.4 m)
# Completed 30.9 % (time last sim = 0.2 m)
# Completed 31.1 % (time last sim = 0.2 m)
# Completed 31.2 % (time last sim = 0.2 m)
# Completed 31.4 % (time last sim = 0.2 m)
# Completed 31.5 % (time last sim = 0.1 m)
# Completed 31.7 % (time last sim = 0.1 m)
# Completed 31.8 % (time last sim = 0.2 m)
# Completed 32.0 % (time last sim = 0.1 m)
# Completed 32.1 % (time last sim = 0.1 m)
# Completed 32.3 % (time last sim = 0.1 m)
# Completed 32.5 % (time last sim = 0.1 m)
# Completed 32.6 % (time last sim = 0.1 m)
# Completed 32.8 % (time last sim = 0.1 m)
# Completed 32.9 % (time last sim = 0.1 m)
# Completed 33.1 % (time last sim = 0.1 m)
# Completed 33.2 % (time last sim = 0.1 m)
# Completed 33.4 % (time last sim = 0.1 m)
# Completed 33.5 % (time last sim = 0.1 m)
# Completed 33.7 % (time last sim = 0.1 m)
# Completed 33.9 % (time last sim = 0.1 m)
# Completed 34.0 % (time last sim = 0.1 m)
# Completed 34.2 % (time last sim = 0.1 m)
# Completed 34.3 % (time last sim = 0.1 m)
# Completed 34.5 % (time last sim = 0.1 m)
# Completed 34.6 % (time last sim = 0.1 m)
# Completed 34.8 % (time last sim = 0.1 m)
# Completed 34.9 % (time last sim = 0.3 m)
# Completed 35.1 % (time last sim = 0.2 m)
# Completed 35.2 % (time last sim = 0.2 m)
# Completed 35.4 % (time last sim = 0.2 m)
# Completed 35.6 % (time last sim = 0.2 m)
# Completed 35.7 % (time last sim = 0.1 m)
# Completed 35.9 % (time last sim = 0.2 m)
# Completed 36.0 % (time last sim = 0.1 m)
# Completed 36.2 % (time last sim = 0.1 m)
# Completed 36.3 % (time last sim = 0.1 m)
# Completed 36.5 % (time last sim = 0.1 m)
# Completed 36.6 % (time last sim = 0.2 m)
# Completed 36.8 % (time last sim = 0.1 m)
# Completed 37.0 % (time last sim = 0.1 m)
# Completed 37.1 % (time last sim = 0.1 m)
# Completed 37.3 % (time last sim = 0.1 m)
# Completed 37.4 % (time last sim = 0.1 m)
# Completed 37.6 % (time last sim = 0.1 m)
# Completed 37.7 % (time last sim = 0.1 m)
# Completed 37.9 % (time last sim = 0.1 m)
# Completed 38.0 % (time last sim = 0.1 m)
# Completed 38.2 % (time last sim = 0.1 m)
# Completed 38.4 % (time last sim = 0.1 m)
# Completed 38.5 % (time last sim = 0.1 m)
# Completed 38.7 % (time last sim = 0.1 m)
# Completed 38.8 % (time last sim = 0.1 m)
# Completed 39.0 % (time last sim = 0.1 m)
# Completed 39.1 % (time last sim = 0.1 m)
# Completed 39.3 % (time last sim = 0.3 m)
# Completed 39.4 % (time last sim = 0.2 m)
# Completed 39.6 % (time last sim = 0.2 m)
# Completed 39.8 % (time last sim = 0.2 m)
# Completed 39.9 % (time last sim = 0.2 m)
# Completed 40.1 % (time last sim = 0.2 m)
# Completed 40.2 % (time last sim = 0.1 m)
# Completed 40.4 % (time last sim = 0.2 m)
# Completed 40.5 % (time last sim = 0.1 m)
# Completed 40.7 % (time last sim = 0.1 m)
# Completed 40.8 % (time last sim = 0.1 m)
# Completed 41.0 % (time last sim = 0.1 m)
# Completed 41.1 % (time last sim = 0.1 m)
# Completed 41.3 % (time last sim = 0.1 m)
# Completed 41.5 % (time last sim = 0.1 m)
# Completed 41.6 % (time last sim = 0.1 m)
# Completed 41.8 % (time last sim = 0.1 m)
# Completed 41.9 % (time last sim = 0.1 m)
# Completed 42.1 % (time last sim = 0.1 m)
# Completed 42.2 % (time last sim = 0.1 m)
# Completed 42.4 % (time last sim = 0.1 m)
# Completed 42.5 % (time last sim = 0.1 m)
# Completed 42.7 % (time last sim = 0.1 m)
# Completed 42.9 % (time last sim = 0.1 m)
# Completed 43.0 % (time last sim = 0.1 m)
# Completed 43.2 % (time last sim = 0.1 m)
# Completed 43.3 % (time last sim = 0.1 m)
# Completed 43.5 % (time last sim = 0.1 m)
# Completed 43.6 % (time last sim = 0.3 m)
# Completed 43.8 % (time last sim = 0.2 m)
# Completed 43.9 % (time last sim = 0.2 m)
# Completed 44.1 % (time last sim = 0.2 m)
# Completed 44.3 % (time last sim = 0.2 m)
# Completed 44.4 % (time last sim = 0.1 m)
# Completed 44.6 % (time last sim = 0.2 m)
# Completed 44.7 % (time last sim = 0.1 m)
# Completed 44.9 % (time last sim = 0.1 m)
# Completed 45.0 % (time last sim = 0.1 m)
# Completed 45.2 % (time last sim = 0.2 m)
# Completed 45.3 % (time last sim = 0.1 m)
# Completed 45.5 % (time last sim = 0.1 m)
# Completed 45.7 % (time last sim = 0.1 m)
# Completed 45.8 % (time last sim = 0.1 m)
# Completed 46.0 % (time last sim = 0.1 m)
# Completed 46.1 % (time last sim = 0.1 m)
# Completed 46.3 % (time last sim = 0.1 m)
# Completed 46.4 % (time last sim = 0.1 m)
# Completed 46.6 % (time last sim = 0.1 m)
# Completed 46.7 % (time last sim = 0.1 m)
# Completed 46.9 % (time last sim = 0.1 m)
# Completed 47.0 % (time last sim = 0.1 m)
# Completed 47.2 % (time last sim = 0.1 m)
# Completed 47.4 % (time last sim = 0.1 m)
# Completed 47.5 % (time last sim = 0.1 m)
# Completed 47.7 % (time last sim = 0.1 m)
# Completed 47.8 % (time last sim = 0.1 m)
# Completed 48.0 % (time last sim = 0.2 m)
# Completed 48.1 % (time last sim = 0.2 m)
# Completed 48.3 % (time last sim = 0.2 m)
# Completed 48.4 % (time last sim = 0.2 m)
# Completed 48.6 % (time last sim = 0.2 m)
# Completed 48.8 % (time last sim = 0.1 m)
# Completed 48.9 % (time last sim = 0.2 m)
# Completed 49.1 % (time last sim = 0.1 m)
# Completed 49.2 % (time last sim = 0.1 m)
# Completed 49.4 % (time last sim = 0.1 m)
# Completed 49.5 % (time last sim = 0.2 m)
# Completed 49.7 % (time last sim = 0.1 m)
# Completed 49.8 % (time last sim = 0.1 m)
# Completed 50.0 % (time last sim = 0.1 m)
# Completed 50.2 % (time last sim = 0.1 m)
# Completed 50.3 % (time last sim = 0.1 m)
# Completed 50.5 % (time last sim = 0.1 m)
# Completed 50.6 % (time last sim = 0.1 m)
# Completed 50.8 % (time last sim = 0.1 m)
# Completed 50.9 % (time last sim = 0.1 m)
# Completed 51.1 % (time last sim = 0.1 m)
# Completed 51.2 % (time last sim = 0.1 m)
# Completed 51.4 % (time last sim = 0.1 m)
# Completed 51.6 % (time last sim = 0.1 m)
# Completed 51.7 % (time last sim = 0.1 m)
# Completed 51.9 % (time last sim = 0.1 m)
# Completed 52.0 % (time last sim = 0.1 m)
# Completed 52.2 % (time last sim = 0.1 m)
# Completed 52.3 % (time last sim = 0.2 m)
# Completed 52.5 % (time last sim = 0.3 m)
# Completed 52.6 % (time last sim = 0.3 m)
# Completed 52.8 % (time last sim = 0.2 m)
# Completed 53.0 % (time last sim = 0.2 m)
# Completed 53.1 % (time last sim = 0.2 m)
# Completed 53.3 % (time last sim = 0.1 m)
# Completed 53.4 % (time last sim = 0.2 m)
# Completed 53.6 % (time last sim = 0.2 m)
# Completed 53.7 % (time last sim = 0.1 m)
# Completed 53.9 % (time last sim = 0.1 m)
# Completed 54.0 % (time last sim = 0.1 m)
# Completed 54.2 % (time last sim = 0.1 m)
# Completed 54.3 % (time last sim = 0.1 m)
# Completed 54.5 % (time last sim = 0.1 m)
# Completed 54.7 % (time last sim = 0.1 m)
# Completed 54.8 % (time last sim = 0.1 m)
# Completed 55.0 % (time last sim = 0.1 m)
# Completed 55.1 % (time last sim = 0.1 m)
# Completed 55.3 % (time last sim = 0.1 m)
# Completed 55.4 % (time last sim = 0.1 m)
# Completed 55.6 % (time last sim = 0.1 m)
# Completed 55.7 % (time last sim = 0.1 m)
# Completed 55.9 % (time last sim = 0.1 m)
# Completed 56.1 % (time last sim = 0.1 m)
# Completed 56.2 % (time last sim = 0.1 m)
# Completed 56.4 % (time last sim = 0.1 m)
# Completed 56.5 % (time last sim = 0.1 m)
# Completed 56.7 % (time last sim = 0.3 m)
# Completed 56.8 % (time last sim = 0.2 m)
# Completed 57.0 % (time last sim = 0.2 m)
# Completed 57.1 % (time last sim = 0.2 m)
# Completed 57.3 % (time last sim = 0.2 m)
# Completed 57.5 % (time last sim = 0.1 m)
# Completed 57.6 % (time last sim = 0.2 m)
# Completed 57.8 % (time last sim = 0.1 m)
# Completed 57.9 % (time last sim = 0.1 m)
# Completed 58.1 % (time last sim = 0.2 m)
# Completed 58.2 % (time last sim = 0.1 m)
# Completed 58.4 % (time last sim = 0.1 m)
# Completed 58.5 % (time last sim = 0.1 m)
# Completed 58.7 % (time last sim = 0.1 m)
# Completed 58.9 % (time last sim = 0.1 m)
# Completed 59.0 % (time last sim = 0.1 m)
# Completed 59.2 % (time last sim = 0.1 m)
# Completed 59.3 % (time last sim = 0.1 m)
# Completed 59.5 % (time last sim = 0.1 m)
# Completed 59.6 % (time last sim = 0.1 m)
# Completed 59.8 % (time last sim = 0.1 m)
# Completed 59.9 % (time last sim = 0.1 m)
# Completed 60.1 % (time last sim = 0.1 m)
# Completed 60.2 % (time last sim = 0.1 m)
# Completed 60.4 % (time last sim = 0.1 m)
# Completed 60.6 % (time last sim = 0.1 m)
# Completed 60.7 % (time last sim = 0.1 m)
# Completed 60.9 % (time last sim = 0.1 m)
# Completed 61.0 % (time last sim = 0.3 m)
# Completed 61.2 % (time last sim = 0.2 m)
# Completed 61.3 % (time last sim = 0.2 m)
# Completed 61.5 % (time last sim = 0.2 m)
# Completed 61.6 % (time last sim = 0.2 m)
# Completed 61.8 % (time last sim = 0.2 m)
# Completed 62.0 % (time last sim = 0.2 m)
# Completed 62.1 % (time last sim = 0.2 m)
# Completed 62.3 % (time last sim = 0.1 m)
# Completed 62.4 % (time last sim = 0.1 m)
# Completed 62.6 % (time last sim = 0.2 m)
# Completed 62.7 % (time last sim = 0.1 m)
# Completed 62.9 % (time last sim = 0.1 m)
# Completed 63.0 % (time last sim = 0.1 m)
# Completed 63.2 % (time last sim = 0.1 m)
# Completed 63.4 % (time last sim = 0.1 m)
# Completed 63.5 % (time last sim = 0.1 m)
# Completed 63.7 % (time last sim = 0.1 m)
# Completed 63.8 % (time last sim = 0.1 m)
# Completed 64.0 % (time last sim = 0.1 m)
# Completed 64.1 % (time last sim = 0.1 m)
# Completed 64.3 % (time last sim = 0.1 m)
# Completed 64.4 % (time last sim = 0.1 m)
# Completed 64.6 % (time last sim = 0.1 m)
# Completed 64.8 % (time last sim = 0.1 m)
# Completed 64.9 % (time last sim = 0.1 m)
# Completed 65.1 % (time last sim = 0.1 m)
# Completed 65.2 % (time last sim = 0.1 m)
# Completed 65.4 % (time last sim = 0.3 m)
# Completed 65.5 % (time last sim = 0.2 m)
# Completed 65.7 % (time last sim = 0.2 m)
# Completed 65.8 % (time last sim = 0.2 m)
# Completed 66.0 % (time last sim = 0.2 m)
# Completed 66.1 % (time last sim = 0.1 m)
# Completed 66.3 % (time last sim = 0.2 m)
# Completed 66.5 % (time last sim = 0.1 m)
# Completed 66.6 % (time last sim = 0.1 m)
# Completed 66.8 % (time last sim = 0.2 m)
# Completed 66.9 % (time last sim = 0.1 m)
# Completed 67.1 % (time last sim = 0.1 m)
# Completed 67.2 % (time last sim = 0.1 m)
# Completed 67.4 % (time last sim = 0.1 m)
# Completed 67.5 % (time last sim = 0.1 m)
# Completed 67.7 % (time last sim = 0.1 m)
# Completed 67.9 % (time last sim = 0.1 m)
# Completed 68.0 % (time last sim = 0.1 m)
# Completed 68.2 % (time last sim = 0.1 m)
# Completed 68.3 % (time last sim = 0.1 m)
# Completed 68.5 % (time last sim = 0.1 m)
# Completed 68.6 % (time last sim = 0.1 m)
# Completed 68.8 % (time last sim = 0.1 m)
# Completed 68.9 % (time last sim = 0.1 m)
# Completed 69.1 % (time last sim = 0.1 m)
# Completed 69.3 % (time last sim = 0.1 m)
# Completed 69.4 % (time last sim = 0.1 m)
# Completed 69.6 % (time last sim = 0.1 m)
# Completed 69.7 % (time last sim = 0.2 m)
# Completed 69.9 % (time last sim = 0.2 m)
# Completed 70.0 % (time last sim = 0.2 m)
# Completed 70.2 % (time last sim = 0.2 m)
# Completed 70.3 % (time last sim = 0.2 m)
# Completed 70.5 % (time last sim = 0.2 m)
# Completed 70.7 % (time last sim = 0.1 m)
# Completed 70.8 % (time last sim = 0.2 m)
# Completed 71.0 % (time last sim = 0.1 m)
# Completed 71.1 % (time last sim = 0.1 m)
# Completed 71.3 % (time last sim = 0.1 m)
# Completed 71.4 % (time last sim = 0.1 m)
# Completed 71.6 % (time last sim = 0.2 m)
# Completed 71.7 % (time last sim = 0.1 m)
# Completed 71.9 % (time last sim = 0.1 m)
# Completed 72.0 % (time last sim = 0.1 m)
# Completed 72.2 % (time last sim = 0.1 m)
# Completed 72.4 % (time last sim = 0.1 m)
# Completed 72.5 % (time last sim = 0.1 m)
# Completed 72.7 % (time last sim = 0.1 m)
# Completed 72.8 % (time last sim = 0.1 m)
# Completed 73.0 % (time last sim = 0.1 m)
# Completed 73.1 % (time last sim = 0.1 m)
# Completed 73.3 % (time last sim = 0.1 m)
# Completed 73.4 % (time last sim = 0.1 m)
# Completed 73.6 % (time last sim = 0.1 m)
# Completed 73.8 % (time last sim = 0.1 m)
# Completed 73.9 % (time last sim = 0.1 m)
# Completed 74.1 % (time last sim = 0.3 m)
# Completed 74.2 % (time last sim = 0.2 m)
# Completed 74.4 % (time last sim = 0.2 m)
# Completed 74.5 % (time last sim = 0.2 m)
# Completed 74.7 % (time last sim = 0.2 m)
# Completed 74.8 % (time last sim = 0.1 m)
# Completed 75.0 % (time last sim = 0.2 m)
# Completed 75.2 % (time last sim = 0.1 m)
# Completed 75.3 % (time last sim = 0.1 m)
# Completed 75.5 % (time last sim = 0.2 m)
# Completed 75.6 % (time last sim = 0.2 m)
# Completed 75.8 % (time last sim = 0.1 m)
# Completed 75.9 % (time last sim = 0.1 m)
# Completed 76.1 % (time last sim = 0.1 m)
# Completed 76.2 % (time last sim = 0.1 m)
# Completed 76.4 % (time last sim = 0.1 m)
# Completed 76.6 % (time last sim = 0.1 m)
# Completed 76.7 % (time last sim = 0.1 m)
# Completed 76.9 % (time last sim = 0.1 m)
# Completed 77.0 % (time last sim = 0.1 m)
# Completed 77.2 % (time last sim = 0.1 m)
# Completed 77.3 % (time last sim = 0.1 m)
# Completed 77.5 % (time last sim = 0.1 m)
# Completed 77.6 % (time last sim = 0.1 m)
# Completed 77.8 % (time last sim = 0.1 m)
# Completed 78.0 % (time last sim = 0.1 m)
# Completed 78.1 % (time last sim = 0.1 m)
# Completed 78.3 % (time last sim = 0.1 m)
# Completed 78.4 % (time last sim = 0.2 m)
# Completed 78.6 % (time last sim = 0.2 m)
# Completed 78.7 % (time last sim = 0.2 m)
# Completed 78.9 % (time last sim = 0.2 m)
# Completed 79.0 % (time last sim = 0.2 m)
# Completed 79.2 % (time last sim = 0.2 m)
# Completed 79.3 % (time last sim = 0.1 m)
# Completed 79.5 % (time last sim = 0.2 m)
# Completed 79.7 % (time last sim = 0.2 m)
# Completed 79.8 % (time last sim = 0.1 m)
# Completed 80.0 % (time last sim = 0.1 m)
# Completed 80.1 % (time last sim = 0.1 m)
# Completed 80.3 % (time last sim = 0.1 m)
# Completed 80.4 % (time last sim = 0.1 m)
# Completed 80.6 % (time last sim = 0.1 m)
# Completed 80.7 % (time last sim = 0.1 m)
# Completed 80.9 % (time last sim = 0.1 m)
# Completed 81.1 % (time last sim = 0.1 m)
# Completed 81.2 % (time last sim = 0.1 m)
# Completed 81.4 % (time last sim = 0.1 m)
# Completed 81.5 % (time last sim = 0.1 m)
# Completed 81.7 % (time last sim = 0.1 m)
# Completed 81.8 % (time last sim = 0.1 m)
# Completed 82.0 % (time last sim = 0.1 m)
# Completed 82.1 % (time last sim = 0.1 m)
# Completed 82.3 % (time last sim = 0.1 m)
# Completed 82.5 % (time last sim = 0.1 m)
# Completed 82.6 % (time last sim = 0.1 m)
# Completed 82.8 % (time last sim = 0.3 m)
# Completed 82.9 % (time last sim = 0.2 m)
# Completed 83.1 % (time last sim = 0.2 m)
# Completed 83.2 % (time last sim = 0.2 m)
# Completed 83.4 % (time last sim = 0.2 m)
# Completed 83.5 % (time last sim = 0.2 m)
# Completed 83.7 % (time last sim = 0.1 m)
# Completed 83.9 % (time last sim = 0.2 m)
# Completed 84.0 % (time last sim = 0.2 m)
# Completed 84.2 % (time last sim = 0.1 m)
# Completed 84.3 % (time last sim = 0.1 m)
# Completed 84.5 % (time last sim = 0.1 m)
# Completed 84.6 % (time last sim = 0.1 m)
# Completed 84.8 % (time last sim = 0.1 m)
# Completed 84.9 % (time last sim = 0.1 m)
# Completed 85.1 % (time last sim = 0.1 m)
# Completed 85.2 % (time last sim = 0.1 m)
# Completed 85.4 % (time last sim = 0.1 m)
# Completed 85.6 % (time last sim = 0.1 m)
# Completed 85.7 % (time last sim = 0.1 m)
# Completed 85.9 % (time last sim = 0.1 m)
# Completed 86.0 % (time last sim = 0.1 m)
# Completed 86.2 % (time last sim = 0.1 m)
# Completed 86.3 % (time last sim = 0.1 m)
# Completed 86.5 % (time last sim = 0.1 m)
# Completed 86.6 % (time last sim = 0.1 m)
# Completed 86.8 % (time last sim = 0.1 m)
# Completed 87.0 % (time last sim = 0.1 m)
# Completed 87.1 % (time last sim = 0.3 m)
# Completed 87.3 % (time last sim = 0.2 m)
# Completed 87.4 % (time last sim = 0.3 m)
# Completed 87.6 % (time last sim = 0.3 m)
# Completed 87.7 % (time last sim = 0.2 m)
# Completed 87.9 % (time last sim = 0.2 m)
# Completed 88.0 % (time last sim = 0.2 m)
# Completed 88.2 % (time last sim = 0.1 m)
# Completed 88.4 % (time last sim = 0.1 m)
# Completed 88.5 % (time last sim = 0.1 m)
# Completed 88.7 % (time last sim = 0.2 m)
# Completed 88.8 % (time last sim = 0.1 m)
# Completed 89.0 % (time last sim = 0.1 m)
# Completed 89.1 % (time last sim = 0.1 m)
# Completed 89.3 % (time last sim = 0.1 m)
# Completed 89.4 % (time last sim = 0.1 m)
# Completed 89.6 % (time last sim = 0.1 m)
# Completed 89.8 % (time last sim = 0.1 m)
# Completed 89.9 % (time last sim = 0.1 m)
# Completed 90.1 % (time last sim = 0.1 m)
# Completed 90.2 % (time last sim = 0.1 m)
# Completed 90.4 % (time last sim = 0.1 m)
# Completed 90.5 % (time last sim = 0.1 m)
# Completed 90.7 % (time last sim = 0.1 m)
# Completed 90.8 % (time last sim = 0.1 m)
# Completed 91.0 % (time last sim = 0.1 m)
# Completed 91.1 % (time last sim = 0.1 m)
# Completed 91.3 % (time last sim = 0.1 m)
# Completed 91.5 % (time last sim = 0.3 m)
# Completed 91.6 % (time last sim = 0.2 m)
# Completed 91.8 % (time last sim = 0.2 m)
# Completed 91.9 % (time last sim = 0.2 m)
# Completed 92.1 % (time last sim = 0.2 m)
# Completed 92.2 % (time last sim = 0.2 m)
# Completed 92.4 % (time last sim = 0.2 m)
# Completed 92.5 % (time last sim = 0.1 m)
# Completed 92.7 % (time last sim = 0.2 m)
# Completed 92.9 % (time last sim = 0.1 m)
# Completed 93.0 % (time last sim = 0.1 m)
# Completed 93.2 % (time last sim = 0.1 m)
# Completed 93.3 % (time last sim = 0.1 m)
# Completed 93.5 % (time last sim = 0.1 m)
# Completed 93.6 % (time last sim = 0.1 m)
# Completed 93.8 % (time last sim = 0.1 m)
# Completed 93.9 % (time last sim = 0.1 m)
# Completed 94.1 % (time last sim = 0.1 m)
# Completed 94.3 % (time last sim = 0.1 m)
# Completed 94.4 % (time last sim = 0.1 m)
# Completed 94.6 % (time last sim = 0.1 m)
# Completed 94.7 % (time last sim = 0.1 m)
# Completed 94.9 % (time last sim = 0.1 m)
# Completed 95.0 % (time last sim = 0.1 m)
# Completed 95.2 % (time last sim = 0.1 m)
# Completed 95.3 % (time last sim = 0.1 m)
# Completed 95.5 % (time last sim = 0.1 m)
# Completed 95.7 % (time last sim = 0.1 m)
# Completed 95.8 % (time last sim = 0.3 m)
# Completed 96.0 % (time last sim = 0.2 m)
# Completed 96.1 % (time last sim = 0.2 m)
# Completed 96.3 % (time last sim = 0.3 m)
# Completed 96.4 % (time last sim = 0.2 m)
# Completed 96.6 % (time last sim = 0.2 m)
# Completed 96.7 % (time last sim = 0.1 m)
# Completed 96.9 % (time last sim = 0.2 m)
# Completed 97.0 % (time last sim = 0.1 m)
# Completed 97.2 % (time last sim = 0.1 m)
# Completed 97.4 % (time last sim = 0.1 m)
# Completed 97.5 % (time last sim = 0.2 m)
# Completed 97.7 % (time last sim = 0.1 m)
# Completed 97.8 % (time last sim = 0.1 m)
# Completed 98.0 % (time last sim = 0.1 m)
# Completed 98.1 % (time last sim = 0.1 m)
# Completed 98.3 % (time last sim = 0.2 m)
# Completed 98.4 % (time last sim = 0.1 m)
# Completed 98.6 % (time last sim = 0.1 m)
# Completed 98.8 % (time last sim = 0.1 m)
# Completed 98.9 % (time last sim = 0.1 m)
# Completed 99.1 % (time last sim = 0.1 m)
# Completed 99.2 % (time last sim = 0.1 m)
# Completed 99.4 % (time last sim = 0.1 m)
# Completed 99.5 % (time last sim = 0.1 m)
# Completed 99.7 % (time last sim = 0.1 m)
# Completed 99.8 % (time last sim = 0.1 m)
# Completed 100.0 % (time last sim = 0.1 m)
# Total time = 1.5  hr

# %%
kw = 13
print(width[kw]/nm)
plt.plot(wavelengths/um, te[:,kw,0,0])
plt.plot(wavelengths/um, te[:,kw,0,1])
# Out:
# 2000.0000000000002

# %%
plt.plot(wavelengths/um, neff[:,kw,0,0])
plt.plot(wavelengths/um, neff[:,kw,0,1])
