# %% [markdown]
# ### Supercontinuum generation for Stephanie's comb

# %%
import numpy as np
import matplotlib.pyplot as plt
import pynlo
import numpy as np

# %%
plt.rcParams.update({'font.size': 18})

# %%
from scipy.constants import pi, c, epsilon_0
km = 1e3
nm = 1e-9
um = 1e-6
mm = 1e-3
ps = 1e-12
fs = 1e-15
GHz = 1e9
THz = 1e12
pJ = 1e-12
mW = 1e-3

# %%
def dB(num):
    return 10 * np.log10(np.abs(num)**2)

# %% [markdown]
# ## Simulation settings

# %%
Window  = 40   # simulation window (ps)
Steps   = 100     # simulation steps
Points  = 2**14  # simulation points

# %% [markdown]
# ## Pulse settings

# %%
frep = 10*GHz
Pavg = 5
EPP = Pavg/frep
print('Energy = %0.1f pJ' %(EPP/pJ))
# Out:
# Energy = 500.0 pJ

# %%
FWHM    = 0.670  # pulse duration (ps)
pulseWL = 1559.9   # pulse central wavelength (nm)
# EPP     = 500*pJ # Energy per pulse (J)
frep    = 10e3 # Repetition rate MHz
GDD     = 0.0    # Group delay dispersion (ps^2)
TOD     = 0.0    # Third order dispersion (ps^3)

# create the pulse
pulse = pynlo.light.DerivedPulses.SechPulse(power = 1, # Power will be scaled by set_epp
                                            T0_ps                   = FWHM/1.76,
                                            center_wavelength_nm    = pulseWL,
                                            time_window_ps          = Window,
                                            GDD=GDD, TOD=TOD,
                                            NPTS            = Points,
                                            frep_MHz        = frep,
                                            power_is_avg    = False)

# set the pulse energy
pulse.set_epp(EPP)

# %%
plt.plot(pulse.T_ps, abs(pulse.AT)**2)

# %% [markdown]
# ## Fiber 1 settings (5m segment of normal dispersion HNLF)

# %%
def get_betas(D, Dslope, wl):
    b2 = -D*wl**2/(2*pi*c)
    b3 = (wl**2/(2*pi*c))**2 * (Dslope - 2*D/wl)
    return b2,b3

# %%
Length  = 1   # length in m

D = -1.0 #ps/nm/km
Dslope = 0.019
beta2, beta3 = get_betas(D*ps/nm/km, Dslope*ps/nm/nm/km, 1.55*um)

beta2 = beta2/(ps**2/km) # (ps^2/km)
beta3 = beta3/(ps**3/km) # (ps^3/km)
beta4 = 0
# beta2   = -7.265     # (ps^2/km)
# beta3   = 0.06381    # (ps^3/km)
# beta4   = -5.45e-5    # (ps^4/km)
# beta5   = 1e-8

Alpha   = 0.9e-5     # attentuation coefficient (dB/cm)
Gamma   = 11.5    # Gamma (1/(W km))

fibWL   = pulseWL # Center WL of fiber (nm)

Raman   = True    # Enable Raman effect?
Steep   = True    # Enable self steepening?

alpha = np.log((10**(Alpha * 0.1))) * 100  # convert from dB/cm to 1/m

# create the fiber
fiber1 = pynlo.media.fibers.fiber.FiberInstance()
fiber1.generate_fiber(Length, center_wl_nm=fibWL, betas=(beta2, beta3, beta4),
                              gamma_W_m=Gamma * 1e-3, gvd_units='ps^n/km', gain=-alpha)

fig = plt.figure()
ax = fig.add_subplot()
ax.plot(pulse.wl_nm, fiber1.Beta2_to_D(pulse))
ax.set_xlim([1500,1600])
# ax.set_ylim([-2,2])
ax.grid(True)

# %% [markdown]
# ## Fiber 2 settings (0.6m of SMF)

# %%
Length  = 0.6   # length in m

D = 20
Dslope = 0.045
beta2, beta3 = get_betas(D*ps/nm/km, Dslope*ps/nm/nm/km, 1.55*um)

beta2 = beta2/(ps**2/km) # (ps^2/km)
beta3 = beta3/(ps**3/km) # (ps^3/km)
beta4 = 0


Alpha   = 0.9e-5     # attentuation coefficient (dB/cm)
Gamma   = 10.5    # Gamma (1/(W km))

fibWL   = pulseWL # Center WL of fiber (nm)

Raman   = True    # Enable Raman effect?
Steep   = True    # Enable self steepening?

alpha = np.log((10**(Alpha * 0.1))) * 100  # convert from dB/cm to 1/m

# create the fiber
fiber2 = pynlo.media.fibers.fiber.FiberInstance()
fiber2.generate_fiber(Length, center_wl_nm=fibWL, betas=(beta2, beta3, beta4),
                              gamma_W_m=Gamma * 1e-3, gvd_units='ps^n/km', gain=-alpha)

fig = plt.figure()
ax = fig.add_subplot()
ax.plot(pulse.wl_nm, fiber2.Beta2_to_D(pulse))
ax.set_xlim([1500,1600])
# ax.set_ylim([-10,10])
ax.grid(True)

# %% [markdown]
# ## Fiber 3 settings (2m of anomalous dispersion HNLF)

# %%
Length  = 3   # length in m

D = 2
Dslope = 0.019
beta2, beta3 = get_betas(D*ps/nm/km, Dslope*ps/nm/nm/km, 1.55*um)

beta2 = beta2/(ps**2/km) # (ps^2/km)
beta3 = beta3/(ps**3/km) # (ps^3/km)
beta4 = 0

Alpha   = 0.9e-5     # attentuation coefficient (dB/cm)
Gamma   = 10.5    # Gamma (1/(W km))

fibWL   = pulseWL # Center WL of fiber (nm)

Raman   = True    # Enable Raman effect?
Steep   = True    # Enable self steepening?

alpha = np.log((10**(Alpha * 0.1))) * 100  # convert from dB/cm to 1/m

# create the fiber
fiber3 = pynlo.media.fibers.fiber.FiberInstance()
fiber3.generate_fiber(Length, center_wl_nm=fibWL, betas=(beta2, beta3, beta4),
                              gamma_W_m=Gamma * 1e-3, gvd_units='ps^n/km', gain=-alpha)

fig = plt.figure()
ax = fig.add_subplot()
ax.plot(pulse.wl_nm, fiber3.Beta2_to_D(pulse))
ax.set_xlim([1500,1600])
# ax.set_ylim([-2,2])
ax.grid(True)

# %% [markdown]
# ## Propagate

# %%
# Propagation
evol = pynlo.interactions.FourWaveMixing.SSFM.SSFM(local_error=0.005, USE_SIMPLE_RAMAN=True,
                 disable_Raman              = np.logical_not(Raman),
                 disable_self_steepening    = np.logical_not(Steep))

y, AW, AT, pulse_out1 = evol.propagate(pulse_in=pulse, fiber=fiber1, n_steps=Steps)
# y, AW, AT, pulse_out2 = evol.propagate(pulse_in=pulse_out1, fiber=fiber2, n_steps=Steps)
y, AW, AT, pulse_out = evol.propagate(pulse_in=pulse_out1, fiber=fiber3, n_steps=Steps)
# Out:
# Pulse energy before Simple Fiber : 0.49999999999999994 nJ
# pulse energy in  12553.386272598993
# copied as   12553.386272598993
# Step: 0 Distance remaining: 1.0
# Pulse energy after: 0.49839553932590913 nJ
# Step: 1 Distance remaining: 0.99
# Pulse energy after: 0.49839437939860415 nJ
# Step: 2 Distance remaining: 0.98
# Pulse energy after: 0.4983932416128172 nJ
# Step: 3 Distance remaining: 0.97
# Pulse energy after: 0.49839212595484034 nJ
# Step: 4 Distance remaining: 0.96
# Pulse energy after: 0.4983910324062755 nJ
# Step: 5 Distance remaining: 0.95
# Pulse energy after: 0.4983899609442817 nJ
# Step: 88 Distance remaining: 0.36
# Pulse energy after: 0.4813052909435045 nJ
# Step: 89 Distance remaining: 0.32999999999999996
# Pulse energy after: 0.4810636788421937 nJ
# Step: 90 Distance remaining: 0.29999999999999993
# Pulse energy after: 0.48079896661282834 nJ
# Step: 91 Distance remaining: 0.2699999999999999
# Pulse energy after: 0.4806030904123032 nJ
# Step: 92 Distance remaining: 0.23999999999999988
# Pulse energy after: 0.4804531155349683 nJ
# Step: 93 Distance remaining: 0.20999999999999985
# Pulse energy after: 0.48028869336548746 nJ
# Step: 94 Distance remaining: 0.18000000000000016
# Pulse energy after: 0.48010078268623385 nJ
# Step: 95 Distance remaining: 0.15000000000000013
# Pulse energy after: 0.4798979902316391 nJ
# Step: 96 Distance remaining: 0.1200000000000001
# Pulse energy after: 0.4796763056267138 nJ
# Step: 97 Distance remaining: 0.09000000000000008
# Pulse energy after: 0.4793863112760073 nJ
# Step: 98 Distance remaining: 0.06000000000000005
# Pulse energy after: 0.47904862999191156 nJ
# Step: 99 Distance remaining: 0.030000000000000027
# Pulse energy after: 0.47875774880335875 nJ
# Pulse energy after Simple Fiber : 0.4788648303845203 nJ

# %% [markdown]
# ### That's it! Physics complete. Just plotting commands from here!

# %%
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111)
ax.plot(pulse.wl_nm,    dB(pulse_out.AW),  color = 'r')
ax.plot(pulse.wl_nm,    dB(pulse.AW),  color = 'b')
ax.set_xlim([1100,2200])
ax.set_ylim([-100,0])
# Out:
# (-100.0, 0.0)

# %%
# set up plots for the results:a
fig = plt.figure(figsize=(20,20))
ax0 = plt.subplot2grid((3,2), (0, 0), rowspan=1)
ax1 = plt.subplot2grid((3,2), (0, 1), rowspan=1)
ax2 = plt.subplot2grid((3,2), (1, 0), rowspan=1, sharex=ax0)
ax3 = plt.subplot2grid((3,2), (1, 1), rowspan=1, sharex=ax1)

F = pulse.F_THz     # Frequency grid of pulse (THz)



zW = dB( np.transpose(AW)[:, (F > 0)] )
zT = dB( np.transpose(AT) )

y_mm = y * 1e3 # convert distance to mm

ax0.plot(pulse_out.F_THz,    dB(pulse_out.AW),  color = 'r')
ax1.plot(pulse_out.T_ps,     dB(pulse_out.AT),  color = 'r')

ax0.plot(pulse.F_THz,    dB(pulse.AW),  color = 'b')
ax1.plot(pulse.T_ps,     dB(pulse.AT),  color = 'b')

extent = (np.min(F[F > 0]), np.max(F[F > 0]), 0, Length)
ax2.imshow(zW, extent=extent,
           vmin=np.max(zW) - 40.0, vmax=np.max(zW),
           aspect='auto', origin='lower')

extent = (np.min(pulse.T_ps), np.max(pulse.T_ps), np.min(y_mm), Length)
ax3.imshow(zT, extent=extent,
           vmin=np.max(zT) - 40.0, vmax=np.max(zT),
           aspect='auto', origin='lower')


ax0.set_ylabel('Intensity (dB)')
ax0.set_ylim( - 80,  0)
ax1.set_ylim( - 40, 40)

ax2.set_ylabel('Propagation distance (mm)')
ax2.set_xlabel('Frequency (THz)')
ax2.set_xlim(0,400)

ax3.set_xlabel('Time (ps)')

plt.show()
# Out:
# C:\Users\luish\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log10
